# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
x = np.random.uniform(-3, 3, 100)
X = x.reshape(-1, 1)
y = 0.5*x + 3 + np.random.normal(0, 1, size=100)

plt.scatter(X, y)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

def fit_plot(algo, X, y):
    np.random.seed(666)
    X_train, X_test, y_train, y_test = train_test_split(X, y)
    algo.fit(X_train, y_train)
    y_predict = algo.predict(X_test)
    print('mean_squared_error=', mean_squared_error(y_test, y_predict))

    X_plot = np.linspace(-3, 3, 100).reshape(100, 1)
    y_plot = algo.predict(X_plot)
    plt.scatter(x, y)
    plt.plot(X_plot[:,0], y_plot, color='r')
    plt.axis([-3, 3, 0, 6])
    plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

def poly(degree=2):
    return Pipeline([
        ('poly', PolynomialFeatures(degree=degree)),
        ('std_scaler', StandardScaler()),
        ('lr', LinearRegression())])

fit_plot(poly(20), X, y)
# Out:
# mean_squared_error= 167.9401085999025

# %%
from sklearn.linear_model import Ridge

def poly_ridge(degree=2, alpha=0.001):
    return Pipeline([
        ('poly', PolynomialFeatures(degree=degree)),
        ('std_scaler', StandardScaler()),
        ('lr', Ridge(alpha=alpha))])

fit_plot(poly_ridge(20, 1), X, y)
# Out:
# mean_squared_error= 1.1888759304218461
