# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.empty((100, 2))
X[:,0] = np.random.uniform(0., 100., size=100)
X[:,1] = 0.75 * X[:,0] + 3. + np.random.normal(0, 10., size=100)

# %%
import os
import sys
sys.path.append('/mycode/code-basic-machine-learning/07-PCA/7.5-pca-in-data-transform/')

from myML.PCA import PCA

pca = PCA(n_components=2)
pca.fit(X)
print("pca.components_=", pca.components_)

pca = PCA(n_components=1)
pca.fit(X)
print("pca.components_=", pca.components_)
# Out:
# pca.components_= [[ 0.76432917  0.64482627]
#  [ 0.64482898 -0.76432689]]
# pca.components_= [[0.76432922 0.64482621]]

# %%
X_reduction = pca.transform(X)
X_restore = pca.inverse_transform(X_reduction)
plt.scatter(X[:,0], X[:,1], color='b', alpha=0.5)
plt.scatter(X_restore[:,0], X_restore[:,1], color='r', alpha=0.5)
plt.show()
